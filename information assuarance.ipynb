# %% [markdown]
# >*Def* : trying to assure that our system will uphold and maintain in accordance to the CIA triad.
# * Achieved by implimenting a security architecture and ,anagement program
# * it will entail of ;
# 1. access control
# 2. Network security
# 3. Infrastructure Security
# 4. Application Security
# 5. Education awareness
# 6. Security Operations
# 7. Legal $ regulatories
# 8. Disaster recovery
# 9. Encryption
#
# ##Information security framework##
# ---
# >*Def*: A series of doxumented processes used for security control in a company
# * its like a blueprint for building an information security program to manage risks and reduce vulnerabilities
#
# >Popular Frameworks include:
# 1. PCI DSS
# 2. ISO 27001/27002
# 3. CIS Critical Security Controls
# 4. NIT Framework for Improving Critical Infrastructure
# 5. Sherwood Applied Security Bussiness Architecture (SABSA)
# 6. Control Objectives for IT (COBIT)
# 7. TOGAF
#
# *NB* : **You should use something that have been tested and approved**
#
# ##Common Criteria##
# ---
#
# *Def* :  International set of standardized guidelines and specifications
# > it assigns an Evaluation Assuarance level to a specific product.
#
# >It ensures that certified products meet an agreed-upon security standard for government deployment.
#
# >Some examples of the Evaluation Assuarance levels include;
# ![image.png](data:image/png;base64,...)
