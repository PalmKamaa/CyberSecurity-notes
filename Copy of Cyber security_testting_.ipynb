# %% [markdown]
# #Testing
# *There are different testing types in hacking;
# ##1. white box test
# sth internal team do, have complete visibility of the system, one is more thourough.
#
# ##2. grey box
# tester have some visibility on the system.
#
#   ## 3. black box
# tester have no visibility of the system,
# they come out blind like a real hacker , one need to do some digging

# %% [markdown]
# * In hacking you will have to learn all the tools lik those the black hat hacker use.
#
# * In practicing your skills, there are alot of labs available so as to perform this, it will aid to keep the lab away from a production enviromnent
#
# * You can download **pre-configured "targets"**  you can practice on such as;
#
# 1.  DVWA/ multilidae/ Metasploitavle 1, 2, or 3
# 2.  OWASP web testing eviromnent/ WebGoat
# 3. OWASP iGoat
# 4. OWASP Android Crackmes
# 5. bWAPP /Bee-Box
# 6. Kioptrixx Level 1-4
# 7. VMs from Vulnhub
#
#
# * One  of the best way to practice is creating a virtualized practice enviromnent.
# * In some cases you may need physical machines so as to do some configuration, to which at this point you can look for one.
#
# ## Virtual machines
# * You can set up a single host computer to run several guest computers inside it instead of buying alot of computers each runnig a different operating system.
# *Each virtual machine(VM) have its own NIC( Network interface Card), IP address, MAC address, CPU, RAMM disks and operating system, etc
# * on the network it will look like a host on its own
# * some common include;
# 1. VMware
# 2. Virtual Box
# 3. Hyper-V
# 4. Bluestacks
# 5. Genymotion
# 6. iPadia
#
#
# ##vritualized container
# * One can also get also use a virtualized container
# *Its just a VM only for only just one app, just a few files to run one app only
# * Some Popular ones include:
# 1. Docker
# 2. Podman
# 3. ZeroVM
# 4. Kubernetes

# %% [markdown]
# hello :grin:
