# %% [markdown]
# **Javascript**
# --
# * Used in web applications develoment, both backend and frontend develoment.
#
# First js code:

# %%
# javascript: alert("Hello You")
# this is not a ppython code, its just that since there aint a js debugger, we just put the code here

# %% [markdown]
# That aint the ideal way of writing website, we normally used an ide < Visual Studio code>
#
# Another way to use JS in chrome or any other web browser, is:
# 1. open web broswer
# 2. right click on an empty column/ space
# 3. inspect option
# 4. choose console
# 5. there you can prompt it as if you are on an editor
#
# always have your website updated to github
